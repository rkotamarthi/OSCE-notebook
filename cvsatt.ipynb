# %%
import sys
print(sys.executable) 
# !/opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install --upgrade pip
# !/opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install pandas
# !/opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install matplotlib
# !/opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install statsmodels    
# !/opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install seaborn
# Out:
# /opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python
# ...
#   Using cached contourpy-1.3.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.4 kB)
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#   Using cached kiwisolver-1.4.8-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.2 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 5.0 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Using cached contourpy-1.3.1-cp313-cp313-macosx_11_0_arm64.whl (255 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 5.0 MB/s eta 0:00:005.1 MB/s eta 0:00:01
# Using cached kiwisolver-1.4.8-cp313-cp313-macosx_11_0_arm64.whl (65 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 5.2 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
data_Briceni = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Briceni.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Soroca = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Soroca.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Camenca = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Camenca.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Ribnita = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Ribnita.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Balti = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Balti.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Falesti = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Falesti.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Baltata = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Baltata.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Bravicea = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Bravicea.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Cahul = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Cahul.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Chisinau = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Chisinau.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Ciadir_Lunga = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Ciadir_Lunga.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Codrii = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Codrii.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Comrat = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Comrat.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Cornesti = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Cornesti.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Dubasari = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Dubasari.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Leova = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Leova.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Stefan_Comrat = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Stefan-Comrat.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Stefan_Voda = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Stefan-Voda.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Tiraspol = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Tiraspol.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
data_Camenca.head
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/rx/763z3qy10bx76yp59pyh1r780000gq/T/ipykernel_5644/4086764143.py in ?()
#       2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4 #data_Briceni = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Briceni.csv", sep=',',skiprows=1,parse_dates={'date': ['Years', 'Month', 'Date']}, encoding = "ISO-8859-1")
#       5 data_Briceni = pd.read_csv("/Users/raok/Desktop/OSCE/data_1994_2023.Briceni.csv", sep=',',skiprows=1, encoding = "ISO-8859-1")
# ----> 6 data_Briceni['datetime'] = pd.to_datetime(data_Briceni['Years'].astype(str),data_Briceni['Month'].astype(str),data_Briceni['Date'].astype(str),format='%Y%m%d')
#       7 data.Briceni.head
#       8
# ...

# %%
#
import matplotlib.dates as mdates
import datetime as dt

import statsmodels.api as sm
plt.figure(figsize=(12, 6))
data_fBriceni = data_Briceni[(data_Briceni['Maximum_temperature(C)'] >= -100)]
data_fSoroca = data_Soroca[(data_Soroca['Maximum_temperature(C)'] >= -100)]
data_fCamenca = data_Camenca[(data_Camenca['Maximum_temperature(C)'] >= -100)]
data_fRibnita = data_Ribnita[(data_Ribnita['Maximum_temperature(C)'] >= -100)]
data_fBalti = data_Balti[(data_Balti['Maximum_temperature(C)'] >= -100)]
data_fFalesti = data_Falesti[(data_Falesti['Maximum_temperature(C)'] >= -100)]
data_fBaltata = data_Baltata[(data_Baltata['Maximum_temperature(C)'] >= -100)]
data_fLeova = data_Leova[(data_Leova['Maximum_temperature(C)'] >= -100)]
data_fTiraspol = data_Tiraspol[(data_Tiraspol['Maximum_temperature(C)'] >= -100)]

Max_temp1 = data_fBriceni['Maximum_temperature(C)']
Max_temp2 = data_fSoroca['Maximum_temperature(C)']
Max_temp3 = data_fCamenca['Maximum_temperature(C)']
Max_temp4 = data_fRibnita['Maximum_temperature(C)']
Max_temp5 = data_fBalti['Maximum_temperature(C)']
Max_temp6 = data_fFalesti['Maximum_temperature(C)']
Max_temp7 = data_fBaltata['Maximum_temperature(C)']
Max_temp8 = data_fLeova['Maximum_temperature(C)']
Max_temp9 = data_fTiraspol['Maximum_temperature(C)']

Time1 = data_fBriceni['date']
Time2 = data_fSoroca['date']
Time3 = data_fCamenca['date']
Time4 = data_fRibnita['date']
Time5 = data_fBalti['date']
Time6 = data_fFalesti['date']
Time7 = data_fBaltata['date']
Time8 = data_fLeova['date']
Time9 = data_fLeova['date']

#fig, ax = plt()
ax = plt.gca()
plt.plot(Time1,Max_temp1,"^")
plt.plot(Time2,Max_temp2,"*")
plt.plot(Time3,Max_temp3,"s")
plt.plot(Time4,Max_temp4,"d")
plt.plot(Time5,Max_temp5,"-b")
plt.plot(Time6,Max_temp6,"-g")
plt.plot(Time7,Max_temp7,"-r")
plt.plot(Time8,Max_temp8,"-y")
plt.plot(Time9,Max_temp9,"-y")
##plt.plot(Time,Min_temp, "-b")
#locator = mdates.MonthLocator(interval=6)
#plt.gca().xaxis.set_major_locator(locator)
#xaxis.set_major_locator(mdates.MonthLocator(interval=3))
# Set the formatter for month names
#xaxis.set_major_formatter(mdates.DateFormatter('%b'))
fmt = mdates.DateFormatter('%b')  # Use '%B' for full month names
#plt.gca().xaxis.set_major_formatter(fmt)
ax.set_ylim([-30, 50])
# Rotate date labels for better readability (optional)
plt.xticks(rotation=45)

plt.gcf().autofmt_xdate()
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title('Temperature Plot')
#plt.legend(["Max", "Min"], loc="lower right")
plt.legend(["Briceni","Soroca","Camenca","Ribnita","Balti","Falesti","Baltata","Leova","Tiraspol"], loc="lower right" )
plt.show()

# %%
plt.figure(figsize=(12, 6))
data_fBravicea = data_Bravicea[(data_Bravicea['Maximum_temperature(C)'] >= -100)]
data_fCahul = data_Cahul[(data_Cahul['Maximum_temperature(C)'] >= -100)]
data_fChisinau = data_Chisinau[(data_Chisinau['Maximum_temperature(C)'] >= -100)]
data_fCiadir_Lunga=data_Ciadir_Lunga[(data_Ciadir_Lunga['Maximum_temperature(C)'] >= -100)]
data_fCodrii = data_Codrii[(data_Codrii['Maximum_temperature(C)'] >= -100)]
data_fComrat = data_Comrat[(data_Comrat['Maximum_temperature(C)'] >= -100)]
data_fCornesti = data_Cornesti[(data_Cornesti['Maximum_temperature(C)'] >= -100)]
data_fDubasari = data_Dubasari[(data_Dubasari['Maximum_temperature(C)'] >= -100)]
data_fStefan_Comrat = data_Stefan_Comrat[(data_Stefan_Comrat['Maximum_temperature(C)'] >= -100)]
data_fStefan_Voda = data_Stefan_Voda[(data_Stefan_Voda['Maximum_temperature(C)'] >= -100)]

Max_temp1 = data_fBravicea['Maximum_temperature(C)']
Max_temp2 = data_fCahul['Maximum_temperature(C)']
Max_temp3 = data_fChisinau['Maximum_temperature(C)']
Max_temp4 = data_fCiadir_Lunga['Maximum_temperature(C)']
Max_temp5 = data_fCodrii['Maximum_temperature(C)']
Max_temp6 = data_fComrat['Maximum_temperature(C)']
Max_temp7 = data_fCornesti['Maximum_temperature(C)']
Max_temp8 = data_fDubasari['Maximum_temperature(C)']
Max_temp9 = data_fStefan_Comrat['Maximum_temperature(C)']
Max_temp10 = data_fStefan_Voda['Maximum_temperature(C)']

Time1 = data_fBravicea['date']
Time2 = data_fCahul['date']
Time3 = data_fChisinau['date']
Time4 = data_fCiadir_Lunga['date']
Time5 = data_fCodrii['date']
Time6 = data_fComrat['date']
Time7 = data_fCornesti['date']
Time8 = data_fDubasari['date']
Time9 = data_fStefan_Comrat['date']
Time10 = data_fStefan_Voda['date']

#fig, ax = plt()
ax = plt.gca()
plt.plot(Time1,Max_temp1,"^")
plt.plot(Time2,Max_temp2,"*")
plt.plot(Time3,Max_temp3,"x")
plt.plot(Time4,Max_temp4,"d")
plt.plot(Time5,Max_temp5,"-b")
plt.plot(Time6,Max_temp6,"-g")
plt.plot(Time7,Max_temp7,"-r")
plt.plot(Time8,Max_temp8,"-y")
plt.plot(Time9,Max_temp9,"-y")
plt.plot(Time10,Max_temp10,"-y")
##plt.plot(Time,Min_temp, "-b")

#locator = mdates.MonthLocator(interval=6)
#plt.gca().xaxis.set_major_locator(locator)
#xaxis.set_major_locator(mdates.MonthLocator(interval=3))
# Set the formatter for month names
#xaxis.set_major_formatter(mdates.DateFormatter('%b'))
fmt = mdates.DateFormatter('%b')  # Use '%B' for full month names
#plt.gca().xaxis.set_major_formatter(fmt)
ax.set_ylim([-30, 50])
# Rotate date labels for better readability (optional)
plt.xticks(rotation=45)

plt.gcf().autofmt_xdate()
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title('Temperature Plot')
#plt.legend(["Max", "Min"], loc="lower right")
plt.legend(["Bravicea","Cahul","Chisinau","Ciadir Lunga","Codrii","Comrat","Cornesti","Dubsari","Stefan-Comrat","Stefan-Voda"], loc="lower right" )
plt.show()

# %%
import statsmodels.api as sm
import datetime as dt

plt.figure(figsize=(12, 6))
Max_temp = data_Briceni['Maximum_temperature(C)']
#Max_temp2 = data_Soroca['Maximum_temperature(C)']
#
Max_temp= pd.to_numeric(Max_temp)
Time = data_Briceni['date']
#
ax = plt.gca()
#
#df['date_ordinal'] = df['date'].apply(lambda x: x.toordinal())
data_Briceni['date_ordinal'] = data_Briceni['date'].apply(lambda x: x.toordinal())
#data_Briceni['datex']=data_Briceni['datex'].map(dt.datetime.toordinal)
Timex = data_Briceni['date_ordinal']
Timex = sm.add_constant(Timex)
model = sm.OLS(Max_temp, Timex)
results = model.fit()

print(results.summary())
#
fmt = mdates.DateFormatter('%b')  # Use '%B' for full month names
#
plt.plot(data_Briceni['date'],results.fittedvalues, 'k-')
plt.plot(data_Briceni['date'],Max_temp, 'go', ms=2)

ax.set_ylim([-30, 50])

#trend = regression.predict(beta=regression.beta) 
#data_Briceni.assign(fit=results.fittedvalues).plot(x='date', y='fit', ax=ax)
# Rotate date labels for better readability (optional)
plt.xticks(rotation=45)
#x = mdates.datestr2num(Time1)

plt.gcf().autofmt_xdate()
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title('Temperature Plot with a linear trend line')
#plt.legend(["Max", "Min"], loc="lower right")
plt.legend(["Briceni"], loc="lower right" )
plt.show()
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Maximum_temperature(C)   R-squared:                       0.007
# Model:                                OLS   Adj. R-squared:                  0.007
# Method:                     Least Squares   F-statistic:                     74.05
# Date:                    Wed, 12 Mar 2025   Prob (F-statistic):           8.68e-18
# Time:                            13:17:22   Log-Likelihood:                -41721.
# No. Observations:                   10957   AIC:                         8.345e+04
# Df Residuals:                       10955   BIC:                         8.346e+04
# Df Model:                               1
# Covariance Type:                nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         -193.6755     24.147     -8.021      0.000    -241.007    -146.344
# ...

# %%
plt.figure(figsize=(12, 6))
Min_temp = data_Briceni['Minimum_temperature(C)']
#Max_temp2 = data_Soroca['Maximum_temperature(C)']
#
Min_temp= pd.to_numeric(Min_temp)
Time = data_Briceni['date']

#
ax = plt.gca()
#

data_Briceni['date_ordinal'] = data_Briceni['date'].apply(lambda x: x.toordinal())

Timex = data_Briceni['date_ordinal']
Timex = sm.add_constant(Timex)
#
model = sm.OLS(Min_temp, Timex)
results = model.fit()
#
print(results.summary())
#
fmt = mdates.DateFormatter('%b')  # Use '%B' for full month names
#
plt.plot(data_Briceni['date'],results.fittedvalues, 'k-')
plt.plot(data_Briceni['date'],Min_temp, 'go', ms=2)
#
ax.set_ylim([-30, 50])
#
plt.xticks(rotation=45)

plt.gcf().autofmt_xdate()
plt.xlabel('Time')
plt.ylabel('Minimum Temperature')
plt.title('Minimum Temperature Plot with a linear trend line')
#plt.legend(["Max", "Min"], loc="lower right")
plt.legend(["Briceni"], loc="lower right" )
plt.show()
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Minimum_temperature(C)   R-squared:                       0.003
# Model:                                OLS   Adj. R-squared:                  0.003
# Method:                     Least Squares   F-statistic:                     35.06
# Date:                    Wed, 12 Mar 2025   Prob (F-statistic):           3.29e-09
# Time:                            13:17:28   Log-Likelihood:                -39000.
# No. Observations:                   10957   AIC:                         7.800e+04
# Df Residuals:                       10955   BIC:                         7.802e+04
# Df Model:                               1
# Covariance Type:                nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         -106.3453     18.838     -5.645      0.000    -143.270     -69.420
# ...

# %%
plt.figure(figsize=(12, 6))
#Max_temp1 = data_Soroco['Maximum_temperature(C)']
Max_temp = data_Soroca['Maximum_temperature(C)']
#
Max_temp= pd.to_numeric(Max_temp)
#Time1 = data_Briceni['date']
Time = data_Soroca['date']
#
ax = plt.gca()
#
#df['date_ordinal'] = df['date'].apply(lambda x: x.toordinal())
data_Soroca['date_ordinal'] = data_Soroca['date'].apply(lambda x: x.toordinal())
#data_Briceni['datex']=data_Briceni['datex'].map(dt.datetime.toordinal)
Timex = data_Soroca['date_ordinal']
Timex = sm.add_constant(Timex)
model = sm.OLS(Max_temp, Timex)
results = model.fit()

print(results.summary())
#ax.scatter(Timex,Max_temp1,"*")
#plt.plot(Timex,Max_temp1, "*")
#
fmt = mdates.DateFormatter('%b')  # Use '%B' for full month names
#
plt.plot(data_Soroca['date'],results.fittedvalues, 'k-')
plt.plot(data_Soroca['date'],Max_temp, 'go', ms=2)

ax.set_ylim([-30, 50])
#
plt.xticks(rotation=45)


plt.gcf().autofmt_xdate()
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title('MAximum Temperature Plot with a linear trend line')
#plt.legend(["Max", "Min"], loc="lower right")
plt.legend(["Soroca"], loc="lower right" )
plt.show()
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Maximum_temperature(C)   R-squared:                       0.001
# Model:                                OLS   Adj. R-squared:                  0.001
# Method:                     Least Squares   F-statistic:                     9.724
# Date:                    Wed, 12 Mar 2025   Prob (F-statistic):            0.00182
# Time:                            13:17:34   Log-Likelihood:                -69349.
# No. Observations:                   10957   AIC:                         1.387e+05
# Df Residuals:                       10955   BIC:                         1.387e+05
# Df Model:                               1
# Covariance Type:                nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         -924.3674    300.576     -3.075      0.002   -1513.551    -335.184
# ...

# %%
plt.figure(figsize=(12, 6))
#Max_temp1 = data_Soroco['Maximum_temperature(C)']
Min_temp = data_Soroca['Minimum_temperature(C)']
#
Min_temp= pd.to_numeric(Min_temp)
#Time1 = data_Briceni['date']
Time = data_Soroca['date']
#
ax = plt.gca()
#
#df['date_ordinal'] = df['date'].apply(lambda x: x.toordinal())
data_Soroca['date_ordinal'] = data_Soroca['date'].apply(lambda x: x.toordinal())
#data_Briceni['datex']=data_Briceni['datex'].map(dt.datetime.toordinal)
Timex = data_Soroca['date_ordinal']
Timex = sm.add_constant(Timex)
model = sm.OLS(Min_temp, Timex)
results = model.fit()

print(results.summary())
#
fmt = mdates.DateFormatter('%b')  # Use '%B' for full month names
#
plt.plot(data_Soroca['date'],results.fittedvalues, 'k-')
plt.plot(data_Soroca['date'],Min_temp, 'go', ms=2)

ax.set_ylim([-30, 50])
#
plt.xticks(rotation=45)


plt.gcf().autofmt_xdate()
plt.xlabel('Time')
plt.ylabel('Temperature')
plt.title('Minimum Temperature Plot with a linear trend line')
#plt.legend(["Max", "Min"], loc="lower right")
plt.legend(["Soroca"], loc="lower right" )
plt.show()
# Out:
#                               OLS Regression Results
# ...
# Dep. Variable:     Minimum_temperature(C)   R-squared:                       0.001
# Model:                                OLS   Adj. R-squared:                  0.001
# Method:                     Least Squares   F-statistic:                     7.419
# Date:                    Wed, 12 Mar 2025   Prob (F-statistic):            0.00646
# Time:                            13:17:40   Log-Likelihood:                -69325.
# No. Observations:                   10957   AIC:                         1.387e+05
# Df Residuals:                       10955   BIC:                         1.387e+05
# Df Model:                               1
# Covariance Type:                nonrobust
# ...
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# const         -813.3950    299.907     -2.712      0.007   -1401.267    -225.523
# ...

# %%
import seaborn as sns

fig, ax = plt.subplots()
#plt.figure(figsize=(12, 6))
#
Min_temp = data_Soroca['Minimum_temperature(C)']
Max_temp = data_Soroca['Maximum_temperature(C)']
#
Min_temp= pd.to_numeric(Min_temp)
#Time1 = data_Briceni['date']
Time = data_Soroca['date']
#
ax = plt.gca()
ax.set_ylim([-30, 50])

sns.boxplot(x=data_Soroca.date.dt.month,y=Max_temp)

plt.xlabel('Time')
plt.ylabel('Temperature')
##plt.gcf().autofmt_xdate()
plt.suptitle('Monthly Maximum Temperature Plot ')
#plt.legend(["Max", "Min"], loc="lower right")
##plt.legend(["Soroca"], loc="lower right" )
#plt.legend(["Max", "Min"], loc="lower right")
#####


#ax.set_ylim([-30,50])
plt.show()
#
fig, ax = plt.subplots()
#
ax = plt.gca()
ax.set_ylim([-30, 50])
sns.boxplot(x=data_Soroca.date.dt.month,y=Min_temp )

plt.xlabel('Time')
plt.ylabel('Temperature')
##plt.gcf().autofmt_xdate()
plt.suptitle('Monthly Minimum Temperature Plot ')
#plt.legend(["Max", "Min"], loc="lower right")
##plt.legend(["Soroca"], loc="lower right" )
#plt.legend(["Max", "Min"], loc="lower right")
#####


#ax.set_ylim([-30,50])


plt.show()

# %%
#plt.figure(figsize=(12, 6))
#print (data_Soroca.head)
fig, ax = plt.subplots()
precip = data_Soroca['precipitation(mm)']
#Min_temp = data['Minimum_Air_Temperature(C)']
Time = data_Soroca['date']
#fig, ax = plt()
ax = plt.gca()
#ax.set_xlim([xmin, xmax])
#ax.set_ylim([ymin, ymax])

plt.plot(Time, precip, "+")
ax.set_ylim([0.01, 100])
#plt.plot(Time,Min_temp, "-b")
ax.set_yscale('log')
fmt = mdates.DateFormatter('%b')  # Use '%B' for full month names
#plt.gca().xaxis.set_major_formatter(fmt)
# Rotate date labels for better readability (optional)
plt.xticks(rotation=45)

plt.gcf().autofmt_xdate()
plt.xlabel('Time')
plt.ylabel('Precipitation(mm)')

#plt.legend(["Max", "Min"], loc="lower right")
plt.show()
#
fig, ax = plt.subplots()
data_filtered = data_Soroca[(data_Soroca['precipitation(mm)'] >= 0)]
data_filtered['precipitation(mm)']
sns.boxplot(x=data_filtered.date.dt.month,y=precip)
plt.xlabel('Time')
plt.ylabel('Precipitation(mm)')
##plt.gcf().autofmt_xdate()
plt.suptitle('Monthly precipitation Plot ')
plt.show()

# %%
plt.figure(figsize=(12, 6))
wspd = data_Briceni['wind_speed(m/sec)']
#wspd= pd.to_numeric(wspd)
#
Time = data_Briceni['date']
#
ax = plt.gca()
plt.plot(Time, wspd, "*")

ax.set_ylim([0, 30])


fmt = mdates.DateFormatter('%b')  # Use '%B' for full month names
#plt.gca().xaxis.set_major_formatter(fmt)
# Rotate date labels for better readability (optional)
plt.xticks(rotation=45)

plt.gcf().autofmt_xdate()
plt.xlabel('Time')
plt.ylabel('Wind Speed(m/sec)')

plt.title('Wind Speed Plot')
#plt.legend(["Max", "Min"], loc="lower right")
plt.show()
#
fig, ax = plt.subplots()
data_filtered = data_Briceni[(data_Briceni['wind_speed(m/sec)'] >= 0)]
wspd = data_filtered['wind_speed(m/sec)']
sns.boxplot(x=data_filtered.date.dt.month,y=wspd)
plt.xlabel('Time')
plt.ylabel('wind speed (m/sec)')
##plt.gcf().autofmt_xdate()
plt.suptitle('Monthly wind speed Plot ')
plt.show()

# %%
plt.figure(figsize=(12, 6))
wspd = data_Briceni['wind_speed(m/sec)']
wspd= pd.to_numeric(wspd)
#
Time = data_Briceni['date']
#
ax = plt.gca()
#print(wspd)

data_filtered = data_Briceni[(data_Briceni['wind_speed(m/sec)'] >= 0)]
wspd= data_filtered['wind_speed(m/sec)']
# Create the plot
sns.kdeplot(wspd)

# Customize the plot
plt.xticks(rotation=45)
plt.title('Wind Speed PDF')
plt.xlabel('Wind Speed (m/s)')
plt.ylabel('Density')

# Display the plot
plt.show()

# %% [markdown]
# # r
